# %% [markdown]
# # Circuit zolder notebook

# %% [markdown]
# ### TODO:
# 1. Collect additional accurate coordinates and elevation of the route (1000+ data points)
# 2.

# %% [markdown]
# ### Goals:
# 1.

# %%
import gpxpy
import matplotlib.pyplot as plt

# %%
# Load GPX file
with open('circuit-zolder.gpx', 'r') as gpx_file:
    gpx = gpxpy.parse(gpx_file)

# %%
# Extract data
route_data = []
for track in gpx.tracks:
    for segment in track.segments:
        for point in segment.points:
            route_data.append((point.latitude, point.longitude, point.elevation))
# Print data
for lat, lon, ele in route_data:
    print(f"Latitude: {lat}, Longitude: {lon}, Altitude: {ele} m")
# Out:
# Latitude: 50.99539, Longitude: 5.26197, Altitude: 38.0 m
# Latitude: 50.99532, Longitude: 5.26211, Altitude: 38.0 m
# Latitude: 50.99528, Longitude: 5.2622, Altitude: 38.0 m
# Latitude: 50.99522, Longitude: 5.26234, Altitude: 38.0 m
# Latitude: 50.99517, Longitude: 5.26249, Altitude: 38.0 m
# Latitude: 50.99515, Longitude: 5.26255, Altitude: 40.0 m
# Latitude: 50.99509, Longitude: 5.26274, Altitude: 40.0 m
# Latitude: 50.99497, Longitude: 5.26321, Altitude: 40.0 m
# Latitude: 50.99483, Longitude: 5.26373, Altitude: 40.0 m
# Latitude: 50.99471, Longitude: 5.26422, Altitude: 40.0 m
# Latitude: 50.99459, Longitude: 5.26473, Altitude: 40.0 m
# Latitude: 50.99444, Longitude: 5.26535, Altitude: 39.0 m
# Latitude: 50.99441, Longitude: 5.26547, Altitude: 39.0 m
# Latitude: 50.99438, Longitude: 5.26553, Altitude: 39.0 m
# Latitude: 50.99435, Longitude: 5.26558, Altitude: 38.0 m
# Latitude: 50.99432, Longitude: 5.26561, Altitude: 39.0 m
# ...

# %%
# Show elevation on plot
elevation = [ele for lat, lon, ele in route_data]

# Plot elevation
plt.plot(elevation)
plt.ylabel('Elevation (m)')
plt.xlabel('Data point')
plt.title('Elevation profile')
plt.show()

# %%
# #Visualize data points on real map
# import ezgpx
# for lat, lon, ele in route_data:
#     print(f"Latitude: {lat}, Longitude: {lon}, Altitude: {ele} m")

#     # Parse GPX file
#     gpx = ezgpx.GPX("circuit-zolder.gpx")

#     # Simplify (using Ramer-Dougle-Peucker algorithm)
#     gpx.simplify()

#     # Remove metadata
#     gpx.remove_metadata()

#     # Plot with Matplotlib
#     gpx.matplotlib_plot(figsize=(16, 9),
#                         size=50,
#                         color="ele",
#                         cmap=matplotlib.cm.get_cmap("gnuplot", 40),
#                         colorbar=False,
#                         start_point_color="green",
#                         stop_point_color="red",
#                         way_points_color=None,
#                         background="World_Imagery",
#                         offset_percentage=0.04,
#                         dpi=100,
#                         title=gpx.name(),
#                         title_fontsize=20,
#                         watermark=True,
#                         file_path="img_1.png")
